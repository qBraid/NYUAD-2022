# %%
import boto3
from braket.aws import AwsDevice
from braket.devices import LocalSimulator
from braket.circuits import Circuit

# %% [markdown]
# # Installation

# %%
# !pip install amazon-braket-ocean-plugin
# Out:
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# Requirement already satisfied: amazon-braket-ocean-plugin in ./.local/lib/python3.9/site-packages (1.0.9)
# Requirement already satisfied: boltons>=20.0.0 in /opt/conda/lib/python3.9/site-packages (from amazon-braket-ocean-plugin) (21.0.0)
# Requirement already satisfied: colorama>=0.4.3 in /opt/conda/lib/python3.9/site-packages (from amazon-braket-ocean-plugin) (0.4.3)
# Requirement already satisfied: wheel>=0.36.2 in /opt/conda/lib/python3.9/site-packages (from amazon-braket-ocean-plugin) (0.37.0)
# Requirement already satisfied: jsonref in /opt/conda/lib/python3.9/site-packages (from amazon-braket-ocean-plugin) (0.2)
# Requirement already satisfied: amazon-braket-sdk>=1.10.0 in ./.local/lib/python3.9/site-packages (from amazon-braket-ocean-plugin) (1.18.0)
# Requirement already satisfied: boto3>=1.18.13 in ./.local/lib/python3.9/site-packages (from amazon-braket-ocean-plugin) (1.21.30)
# Requirement already satisfied: dimod>=0.8.13 in /opt/conda/lib/python3.9/site-packages (from amazon-braket-ocean-plugin) (0.10.12)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (1.20.3)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.9/site-packages (from amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (1.5.4)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (from amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (2.7.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (1.10.1)
# Requirement already satisfied: coverage==5.5 in /opt/conda/lib/python3.9/site-packages (from amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (5.5)
# Requirement already satisfied: amazon-braket-default-simulator in ./.local/lib/python3.9/site-packages (from amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (1.5.0)
# Requirement already satisfied: backoff in /opt/conda/lib/python3.9/site-packages (from amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (1.11.1)
# Requirement already satisfied: botocore<1.25.0,>=1.24.30 in ./.local/lib/python3.9/site-packages (from boto3>=1.18.13->amazon-braket-ocean-plugin) (1.24.30)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/conda/lib/python3.9/site-packages (from boto3>=1.18.13->amazon-braket-ocean-plugin) (0.5.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.9/site-packages (from boto3>=1.18.13->amazon-braket-ocean-plugin) (1.0.0)
# Requirement already satisfied: pyparsing<3.0.0,>=2.4.7 in /opt/conda/lib/python3.9/site-packages (from dimod>=0.8.13->amazon-braket-ocean-plugin) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.9/site-packages (from botocore<1.25.0,>=1.24.30->boto3>=1.18.13->amazon-braket-ocean-plugin) (1.26.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.9/site-packages (from botocore<1.25.0,>=1.24.30->boto3>=1.18.13->amazon-braket-ocean-plugin) (2.8.2)
# Requirement already satisfied: amazon-braket-schemas in ./.local/lib/python3.9/site-packages (from amazon-braket-default-simulator->amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (1.8.0)
# Requirement already satisfied: opt-einsum in /opt/conda/lib/python3.9/site-packages (from amazon-braket-default-simulator->amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (3.3.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (1.2.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.25.0,>=1.24.30->boto3>=1.18.13->amazon-braket-ocean-plugin) (1.16.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.8.2 in /opt/conda/lib/python3.9/site-packages (from amazon-braket-schemas->amazon-braket-default-simulator->amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (1.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from pydantic<2.0.0,>=1.8.2->amazon-braket-schemas->amazon-braket-default-simulator->amazon-braket-sdk>=1.10.0->amazon-braket-ocean-plugin) (4.1.1)
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)

# %%
# !pip install dwave-ocean-sdk
# Out:
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# Requirement already satisfied: dwave-ocean-sdk in /opt/conda/lib/python3.9/site-packages (4.4.0)
# Requirement already satisfied: penaltymodel==0.16.6 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.16.6)
# Requirement already satisfied: penaltymodel-mip==0.2.6 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.2.6)
# Requirement already satisfied: dwave-greedy==0.2.2 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.2.2)
# Requirement already satisfied: dimod==0.10.12 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.10.12)
# Requirement already satisfied: dwave-preprocessing==0.3.2 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.3.2)
# Requirement already satisfied: dwave-tabu==0.4.3 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.4.3)
# Requirement already satisfied: dwave-cloud-client==0.9.3 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.9.3)
# Requirement already satisfied: minorminer==0.2.7.post0 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.2.7.post0)
# Requirement already satisfied: dwave-qbsolv==0.3.4 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.3.4)
# Requirement already satisfied: penaltymodel-lp==0.1.6 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.1.6)
# Requirement already satisfied: dwave-system==1.12.0 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (1.12.0)
# Requirement already satisfied: dwavebinarycsp==0.1.4 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.1.4)
# Requirement already satisfied: penaltymodel-cache==0.4.5 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.4.5)
# Requirement already satisfied: dwave-networkx==0.8.11 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.8.11)
# Requirement already satisfied: pyqubo==1.2.0 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (1.2.0)
# Requirement already satisfied: dwave-neal==0.5.9 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.5.9)
# Requirement already satisfied: dwave-inspector==0.2.9 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.2.9)
# Requirement already satisfied: dwave-hybrid==0.6.5 in /opt/conda/lib/python3.9/site-packages (from dwave-ocean-sdk) (0.6.5)
# Requirement already satisfied: pyparsing<3.0.0,>=2.4.7 in /opt/conda/lib/python3.9/site-packages (from dimod==0.10.12->dwave-ocean-sdk) (2.4.7)
# Requirement already satisfied: numpy<2.0.0,>=1.19.1 in /opt/conda/lib/python3.9/site-packages (from dimod==0.10.12->dwave-ocean-sdk) (1.20.3)
# Requirement already satisfied: diskcache>=5.2.1 in /opt/conda/lib/python3.9/site-packages (from dwave-cloud-client==0.9.3->dwave-ocean-sdk) (5.4.0)
# Requirement already satisfied: pydantic>=1.7.3 in /opt/conda/lib/python3.9/site-packages (from dwave-cloud-client==0.9.3->dwave-ocean-sdk) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from dwave-cloud-client==0.9.3->dwave-ocean-sdk) (2.8.2)
# Requirement already satisfied: homebase>=1.0 in /opt/conda/lib/python3.9/site-packages (from dwave-cloud-client==0.9.3->dwave-ocean-sdk) (1.0.1)
# Requirement already satisfied: plucky>=0.4.3 in /opt/conda/lib/python3.9/site-packages (from dwave-cloud-client==0.9.3->dwave-ocean-sdk) (0.4.3)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.9/site-packages (from dwave-cloud-client==0.9.3->dwave-ocean-sdk) (8.1.1)
# Requirement already satisfied: requests[socks]>=2.18 in /opt/conda/lib/python3.9/site-packages (from dwave-cloud-client==0.9.3->dwave-ocean-sdk) (2.26.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (from dwave-hybrid==0.6.5->dwave-ocean-sdk) (2.7.1)
# Requirement already satisfied: Flask>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from dwave-inspector==0.2.9->dwave-ocean-sdk) (2.1.1)
# Requirement already satisfied: rectangle-packer>=2.0.1 in /opt/conda/lib/python3.9/site-packages (from minorminer==0.2.7.post0->dwave-ocean-sdk) (2.0.1)
# Requirement already satisfied: fasteners in /opt/conda/lib/python3.9/site-packages (from minorminer==0.2.7.post0->dwave-ocean-sdk) (0.17.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from minorminer==0.2.7.post0->dwave-ocean-sdk) (1.8.0)
# Requirement already satisfied: ortools<10.0.0,>=6.6.4659 in /opt/conda/lib/python3.9/site-packages (from penaltymodel-mip==0.2.6->dwave-ocean-sdk) (9.3.10497)
# Requirement already satisfied: Deprecated>=1.2.12 in /opt/conda/lib/python3.9/site-packages (from pyqubo==1.2.0->dwave-ocean-sdk) (1.2.13)
# Requirement already satisfied: six>=1.15.0 in /opt/conda/lib/python3.9/site-packages (from pyqubo==1.2.0->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.9/site-packages (from Deprecated>=1.2.12->pyqubo==1.2.0->dwave-ocean-sdk) (1.14.0)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/lib/python3.9/site-packages (from Flask>=1.1.1->dwave-inspector==0.2.9->dwave-ocean-sdk) (3.0.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /opt/conda/lib/python3.9/site-packages (from Flask>=1.1.1->dwave-inspector==0.2.9->dwave-ocean-sdk) (4.8.2)
# Requirement already satisfied: Werkzeug>=2.0 in /opt/conda/lib/python3.9/site-packages (from Flask>=1.1.1->dwave-inspector==0.2.9->dwave-ocean-sdk) (2.1.0)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/conda/lib/python3.9/site-packages (from Flask>=1.1.1->dwave-inspector==0.2.9->dwave-ocean-sdk) (2.1.2)
# Requirement already satisfied: absl-py>=0.13 in /opt/conda/lib/python3.9/site-packages (from ortools<10.0.0,>=6.6.4659->penaltymodel-mip==0.2.6->dwave-ocean-sdk) (1.0.0)
# Requirement already satisfied: protobuf>=3.19.4 in /opt/conda/lib/python3.9/site-packages (from ortools<10.0.0,>=6.6.4659->penaltymodel-mip==0.2.6->dwave-ocean-sdk) (3.19.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from pydantic>=1.7.3->dwave-cloud-client==0.9.3->dwave-ocean-sdk) (4.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests[socks]>=2.18->dwave-cloud-client==0.9.3->dwave-ocean-sdk) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests[socks]>=2.18->dwave-cloud-client==0.9.3->dwave-ocean-sdk) (2.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests[socks]>=2.18->dwave-cloud-client==0.9.3->dwave-ocean-sdk) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests[socks]>=2.18->dwave-cloud-client==0.9.3->dwave-ocean-sdk) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.9/site-packages (from requests[socks]>=2.18->dwave-cloud-client==0.9.3->dwave-ocean-sdk) (1.7.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.1->dwave-inspector==0.2.9->dwave-ocean-sdk) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from Jinja2>=3.0->Flask>=1.1.1->dwave-inspector==0.2.9->dwave-ocean-sdk) (2.0.1)
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -tocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)

# %% [markdown]
# # Defining the QUBO

# %%
import qubovert
import numpy as np
import networkx as nx

# %%
class VRPstate:
    def __init__(self, G, num_vehicles):
        self.num_nodes = len(G.nodes)
        self.num_vehicles = num_vehicles
        self.G = G # depot is always node 0
        self.vehicle_locations = [0 for _ in range(self.num_vehicles)]
        self.vehicle_routes = [[] for _ in range(self.num_vehicles)]
        self.visited_nodes = [0 for _ in range(self.num_nodes)]
        
        self.qubo = None
        self.C = None

    def get_cost_matrix(self):
        C = np.zeros((self.num_nodes, self.num_nodes))
        for i in range(self.num_nodes):
            for j in range(i+1, self.num_nodes):
                if self.G.has_edge(i,j): # edge exists
                    C[i,j] = self.G[i][j]['weight']
                    C[j,i] = C[i,j]
                else: # edge doesnt exist
                    path = nx.shortest_path(self.G, source=i, target=j, weight='weight')
                    C[i,j] = sum([self.G[path[i]][path[i+1]]['weight'] for i in range(len(path)-1)]) * 10 * 3**len(path)
                    C[j,i] = C[i,j]
        self.C = C
    
    def A_func(self, A_2, binary_vars):
        for i in range(len(binary_vars)):
            for j in range(i+1, len(binary_vars)):
                self.qubo[(binary_vars[i], binary_vars[j])] += A_2 * 2
        
        for var in binary_vars:
            self.qubo[(var,)] -= A_2 * 1
    
    def add_constraints(self, A_2):
        # Ensure each node is visited by a single vehicle
        for k in range(self.num_nodes):
            binary_vars = []
            for vehicle in range(self.num_vehicles):
                for timestep in range(self.num_nodes):
                    binary_vars.append((vehicle, k, timestep))
            self.A_func(A_2, binary_vars)
            
        # Each vehicle is in one location at one time
        for vehicle in range(self.num_vehicles):
            for timestep in range(self.num_nodes):
                binary_vars = [(vehicle, n, timestep) for n in range(self.num_nodes)]
                self.A_func(A_2, binary_vars)
        
        # Each vehicle is in its current location at time t=0
        for m in range(self.num_vehicles):
            for n in range(self.num_nodes):
                if self.vehicle_locations[m] == n:
                    self.qubo[((m, n, 0),)] -= A_2
                else:
                    self.qubo[((m, n, 0),)] += A_2
    
    def get_qubo(self, A_1=1, A_2=1000):
        self.get_cost_matrix()
        self.qubo = qubovert.QUBO()

        # first order terms
        for i in range(self.num_vehicles):
            for j in range(1, self.num_nodes):
                # returning to depot cost
                self.qubo[((i, j, self.num_nodes),)] += A_1 * self.C[j, 0]
                
        for m in range(self.num_vehicles):
            for n in range(self.num_nodes):
                # travelling from current position cost
                self.qubo[((m, n, 1),)] += A_1 * self.C[n, self.vehicle_locations[m]]
                
        # second order terms
        for m in range(self.num_vehicles):
            for n in range(1, self.num_nodes):
                for i in range(self.num_nodes):
                    for j in range(self.num_nodes):
                        # Add second order term to qubo
                        self.qubo[((m, i, n), (m, j, n+1))] += A_1 * self.C[i, j]
                            
        # Add constraint term Q
        self.add_constraints(A_2)
     
        return self.qubo
    
    def print_routes(self, best_state):
        for vehicle in range(self.num_vehicles):
            total_cost = 0    
            print(f'Vehicle {vehicle}:')
            cur_path = sorted([key for key, val in best_state.items() if val == 1 and key[0] == vehicle], key=lambda v: v[2])
            print(f'\t{self.vehicle_locations[vehicle]} --> ', end='')
            prev_stop = self.vehicle_locations[vehicle]
            for stop in cur_path:
                total_cost += state.C[prev_stop, stop[1]]
                prev_stop = stop[1]
                print(f'{stop[1]} --> ', end='')
            print('END')

            # total cost
            print('\t Total Cost =', total_cost)

# %%
G = nx.com
#G.add_edges_from([(0,4,{'weight':1}), (4,3,{'weight':1}), (1,3,{'weight':1}),
#                  (1,7,{'weight':1}),(7,8,{'weight':1}), (8,6,{'weight':1}), (6,2,{'weight':1}),
#                  (5,4,{'weight':1}),(5,7,{'weight':1}), (5,9,{'weight':1}), (9,11,{'weight':1}),
#                  (11,10,{'weight':1}),(9,12,{'weight':1}), (12,11,{'weight':1}),])
#G.add_edges_from([(0,1,{'weight':1}), (1,2,{'weight':1}), (0,3,{'weight':1}),
#                  (3,4,{'weight':1}),])
nx.draw_spring(G, with_labels=True)
state = VRPstate(G, 1)
state.get_cost_matrix()
print(state.C)

qubo = state.get_qubo()
print(f'Create QUBO with {qubo.num_binary_variables} variables and {qubo.num_terms} terms')
# Out:
# [[0.0000e+00 2.4300e+03 1.3122e+05 5.4000e+02 1.0000e+00 5.4000e+02
#   3.6450e+04 2.4300e+03 9.7200e+03 2.4300e+03 3.6450e+04 9.7200e+03
#   9.7200e+03]
#  [2.4300e+03 0.0000e+00 9.7200e+03 1.0000e+00 5.4000e+02 5.4000e+02
#   2.4300e+03 1.0000e+00 5.4000e+02 2.4300e+03 3.6450e+04 9.7200e+03
#   9.7200e+03]
#  [1.3122e+05 9.7200e+03 0.0000e+00 3.6450e+04 3.6450e+04 9.7200e+03
#   1.0000e+00 2.4300e+03 5.4000e+02 3.6450e+04 4.5927e+05 1.3122e+05
#   1.3122e+05]
#  [5.4000e+02 1.0000e+00 3.6450e+04 0.0000e+00 1.0000e+00 5.4000e+02
#   9.7200e+03 5.4000e+02 2.4300e+03 2.4300e+03 3.6450e+04 9.7200e+03
#   9.7200e+03]
#  [1.0000e+00 5.4000e+02 3.6450e+04 1.0000e+00 0.0000e+00 1.0000e+00
#   9.7200e+03 5.4000e+02 2.4300e+03 5.4000e+02 9.7200e+03 2.4300e+03
#   2.4300e+03]
#  [5.4000e+02 5.4000e+02 9.7200e+03 5.4000e+02 1.0000e+00 0.0000e+00
#   2.4300e+03 1.0000e+00 5.4000e+02 1.0000e+00 2.4300e+03 5.4000e+02
#   5.4000e+02]
#  [3.6450e+04 2.4300e+03 1.0000e+00 9.7200e+03 9.7200e+03 2.4300e+03
#   0.0000e+00 5.4000e+02 1.0000e+00 9.7200e+03 1.3122e+05 3.6450e+04
#   3.6450e+04]
#  [2.4300e+03 1.0000e+00 2.4300e+03 5.4000e+02 5.4000e+02 1.0000e+00
#   5.4000e+02 0.0000e+00 1.0000e+00 5.4000e+02 9.7200e+03 2.4300e+03
#   2.4300e+03]
#  [9.7200e+03 5.4000e+02 5.4000e+02 2.4300e+03 2.4300e+03 5.4000e+02
#   1.0000e+00 1.0000e+00 0.0000e+00 2.4300e+03 3.6450e+04 9.7200e+03
#   9.7200e+03]
#  [2.4300e+03 2.4300e+03 3.6450e+04 2.4300e+03 5.4000e+02 1.0000e+00
#   9.7200e+03 5.4000e+02 2.4300e+03 0.0000e+00 5.4000e+02 1.0000e+00
#   1.0000e+00]
#  [3.6450e+04 3.6450e+04 4.5927e+05 3.6450e+04 9.7200e+03 2.4300e+03
#   1.3122e+05 9.7200e+03 3.6450e+04 5.4000e+02 0.0000e+00 1.0000e+00
#   5.4000e+02]
#  [9.7200e+03 9.7200e+03 1.3122e+05 9.7200e+03 2.4300e+03 5.4000e+02
#   3.6450e+04 2.4300e+03 9.7200e+03 1.0000e+00 1.0000e+00 0.0000e+00
#   1.0000e+00]
#  [9.7200e+03 9.7200e+03 1.3122e+05 9.7200e+03 2.4300e+03 5.4000e+02
#   3.6450e+04 2.4300e+03 9.7200e+03 1.0000e+00 5.4000e+02 1.0000e+00
#   0.0000e+00]]
# Create QUBO with 182 variables and 4081 terms

# %%
result = qubovert.sim.anneal_qubo(qubo.Q, num_anneals=4, anneal_duration=int(1e6))
for i, res in enumerate(result):
    print('Anneal', i+1)
    state.print_routes(res.state)
    print()
# Out:
# Anneal 1
# Vehicle 0:
# 	0 --> 0 --> 4 --> 3 --> 1 --> 7 --> 5 --> 9 --> 11 --> 10 --> 8 --> 6 --> 2 --> END
# 	 Total Cost = 36460.0
#
# Anneal 2
# Vehicle 0:
# 	0 --> 0 --> 4 --> 3 --> 1 --> 10 --> 11 --> 12 --> 9 --> 5 --> 7 --> 8 --> 6 --> END
# 	 Total Cost = 36460.0
#
# Anneal 3
# Vehicle 0:
# 	0 --> 0 --> 4 --> 3 --> 1 --> 7 --> 5 --> 9 --> 11 --> 10 --> 6 --> 8 --> 2 --> END
# 	 Total Cost = 131769.0
#
# Anneal 4
# Vehicle 0:
# 	0 --> 0 --> 10 --> 11 --> 12 --> 9 --> 5 --> 4 --> 3 --> 1 --> 7 --> 8 --> 6 --> END
# 	 Total Cost = 36460.0

# %%
result.best.value
# Out:
# -280.0

# %%
qubo
# Out:
# {((0, 1, 5),): 1.0,
#  ((0, 2, 5),): 16.0,
#  ((0, 3, 5),): 1.0,
#  ((0, 4, 5),): 16.0,
#  ((0, 1, 1),): -199.0,
#  ((0, 2, 1),): -184.0,
#  ((0, 3, 1),): -199.0,
#  ((0, 4, 1),): -184.0,
#  ((0, 0, 1), (0, 1, 2)): 1.0,
#  ((0, 0, 1), (0, 2, 2)): 16.0,
#  ((0, 0, 1), (0, 3, 2)): 1.0,
#  ((0, 0, 1), (0, 4, 2)): 16.0,
#  ((0, 0, 2), (0, 1, 1)): 1.0,
#  ((0, 1, 1), (0, 2, 2)): 1.0,
#  ((0, 1, 1), (0, 3, 2)): 16.0,
#  ((0, 1, 1), (0, 4, 2)): 48.0,
#  ((0, 0, 2), (0, 2, 1)): 16.0,
#  ((0, 1, 2), (0, 2, 1)): 1.0,
#  ((0, 2, 1), (0, 3, 2)): 48.0,
#  ((0, 2, 1), (0, 4, 2)): 128.0,
#  ((0, 0, 2), (0, 3, 1)): 1.0,
#  ((0, 1, 2), (0, 3, 1)): 16.0,
#  ((0, 2, 2), (0, 3, 1)): 48.0,
#  ((0, 3, 1), (0, 4, 2)): 1.0,
#  ((0, 0, 2), (0, 4, 1)): 16.0,
#  ((0, 1, 2), (0, 4, 1)): 48.0,
#  ((0, 2, 2), (0, 4, 1)): 128.0,
#  ((0, 3, 2), (0, 4, 1)): 1.0,
#  ((0, 0, 2), (0, 1, 3)): 1.0,
#  ((0, 0, 2), (0, 2, 3)): 16.0,
#  ((0, 0, 2), (0, 3, 3)): 1.0,
#  ((0, 0, 2), (0, 4, 3)): 16.0,
#  ((0, 0, 3), (0, 1, 2)): 1.0,
#  ((0, 1, 2), (0, 2, 3)): 1.0,
#  ((0, 1, 2), (0, 3, 3)): 16.0,
#  ((0, 1, 2), (0, 4, 3)): 48.0,
#  ((0, 0, 3), (0, 2, 2)): 16.0,
#  ((0, 1, 3), (0, 2, 2)): 1.0,
#  ((0, 2, 2), (0, 3, 3)): 48.0,
#  ((0, 2, 2), (0, 4, 3)): 128.0,
#  ((0, 0, 3), (0, 3, 2)): 1.0,
#  ((0, 1, 3), (0, 3, 2)): 16.0,
#  ((0, 2, 3), (0, 3, 2)): 48.0,
#  ((0, 3, 2), (0, 4, 3)): 1.0,
#  ((0, 0, 3), (0, 4, 2)): 16.0,
#  ((0, 1, 3), (0, 4, 2)): 48.0,
#  ((0, 2, 3), (0, 4, 2)): 128.0,
#  ((0, 3, 3), (0, 4, 2)): 1.0,
#  ((0, 0, 3), (0, 1, 4)): 1.0,
#  ((0, 0, 3), (0, 2, 4)): 16.0,
#  ((0, 0, 3), (0, 3, 4)): 1.0,
#  ((0, 0, 3), (0, 4, 4)): 16.0,
#  ((0, 0, 4), (0, 1, 3)): 1.0,
#  ((0, 1, 3), (0, 2, 4)): 1.0,
#  ((0, 1, 3), (0, 3, 4)): 16.0,
#  ((0, 1, 3), (0, 4, 4)): 48.0,
#  ((0, 0, 4), (0, 2, 3)): 16.0,
#  ((0, 1, 4), (0, 2, 3)): 1.0,
#  ((0, 2, 3), (0, 3, 4)): 48.0,
#  ((0, 2, 3), (0, 4, 4)): 128.0,
#  ((0, 0, 4), (0, 3, 3)): 1.0,
#  ((0, 1, 4), (0, 3, 3)): 16.0,
#  ((0, 2, 4), (0, 3, 3)): 48.0,
#  ((0, 3, 3), (0, 4, 4)): 1.0,
#  ((0, 0, 4), (0, 4, 3)): 16.0,
#  ((0, 1, 4), (0, 4, 3)): 48.0,
#  ((0, 2, 4), (0, 4, 3)): 128.0,
#  ((0, 3, 4), (0, 4, 3)): 1.0,
#  ((0, 0, 4), (0, 1, 5)): 1.0,
#  ((0, 0, 4), (0, 2, 5)): 16.0,
#  ((0, 0, 4), (0, 3, 5)): 1.0,
#  ((0, 0, 4), (0, 4, 5)): 16.0,
#  ((0, 0, 5), (0, 1, 4)): 1.0,
#  ((0, 1, 4), (0, 2, 5)): 1.0,
#  ((0, 1, 4), (0, 3, 5)): 16.0,
#  ((0, 1, 4), (0, 4, 5)): 48.0,
#  ((0, 0, 5), (0, 2, 4)): 16.0,
#  ((0, 1, 5), (0, 2, 4)): 1.0,
#  ((0, 2, 4), (0, 3, 5)): 48.0,
#  ((0, 2, 4), (0, 4, 5)): 128.0,
#  ((0, 0, 5), (0, 3, 4)): 1.0,
#  ((0, 1, 5), (0, 3, 4)): 16.0,
#  ((0, 2, 5), (0, 3, 4)): 48.0,
#  ((0, 3, 4), (0, 4, 5)): 1.0,
#  ((0, 0, 5), (0, 4, 4)): 16.0,
#  ((0, 1, 5), (0, 4, 4)): 48.0,
#  ((0, 2, 5), (0, 4, 4)): 128.0,
#  ((0, 3, 5), (0, 4, 4)): 1.0,
#  ((0, 0, 0), (0, 0, 1)): 200.0,
#  ((0, 0, 0), (0, 0, 2)): 200.0,
#  ((0, 0, 0), (0, 0, 3)): 200.0,
#  ((0, 0, 0), (0, 0, 4)): 200.0,
#  ((0, 0, 1), (0, 0, 2)): 200.0,
#  ((0, 0, 1), (0, 0, 3)): 200.0,
#  ((0, 0, 1), (0, 0, 4)): 200.0,
#  ((0, 0, 2), (0, 0, 3)): 200.0,
#  ((0, 0, 2), (0, 0, 4)): 200.0,
#  ((0, 0, 3), (0, 0, 4)): 200.0,
#  ((0, 0, 0),): -300.0,
#  ((0, 0, 1),): -200.0,
#  ((0, 0, 2),): -200.0,
#  ((0, 0, 3),): -200.0,
#  ((0, 0, 4),): -200.0,
#  ((0, 1, 0), (0, 1, 1)): 200.0,
#  ((0, 1, 0), (0, 1, 2)): 200.0,
#  ((0, 1, 0), (0, 1, 3)): 200.0,
#  ((0, 1, 0), (0, 1, 4)): 200.0,
#  ((0, 1, 1), (0, 1, 2)): 200.0,
#  ((0, 1, 1), (0, 1, 3)): 200.0,
#  ((0, 1, 1), (0, 1, 4)): 200.0,
#  ((0, 1, 2), (0, 1, 3)): 200.0,
#  ((0, 1, 2), (0, 1, 4)): 200.0,
#  ((0, 1, 3), (0, 1, 4)): 200.0,
#  ((0, 1, 0),): -100.0,
#  ((0, 1, 2),): -200.0,
#  ((0, 1, 3),): -200.0,
#  ((0, 1, 4),): -200.0,
#  ((0, 2, 0), (0, 2, 1)): 200.0,
#  ((0, 2, 0), (0, 2, 2)): 200.0,
#  ((0, 2, 0), (0, 2, 3)): 200.0,
#  ((0, 2, 0), (0, 2, 4)): 200.0,
#  ((0, 2, 1), (0, 2, 2)): 200.0,
#  ((0, 2, 1), (0, 2, 3)): 200.0,
#  ((0, 2, 1), (0, 2, 4)): 200.0,
#  ((0, 2, 2), (0, 2, 3)): 200.0,
#  ((0, 2, 2), (0, 2, 4)): 200.0,
#  ((0, 2, 3), (0, 2, 4)): 200.0,
#  ((0, 2, 0),): -100.0,
#  ((0, 2, 2),): -200.0,
#  ((0, 2, 3),): -200.0,
#  ((0, 2, 4),): -200.0,
#  ((0, 3, 0), (0, 3, 1)): 200.0,
#  ((0, 3, 0), (0, 3, 2)): 200.0,
#  ((0, 3, 0), (0, 3, 3)): 200.0,
#  ((0, 3, 0), (0, 3, 4)): 200.0,
#  ((0, 3, 1), (0, 3, 2)): 200.0,
#  ((0, 3, 1), (0, 3, 3)): 200.0,
#  ((0, 3, 1), (0, 3, 4)): 200.0,
#  ((0, 3, 2), (0, 3, 3)): 200.0,
#  ((0, 3, 2), (0, 3, 4)): 200.0,
#  ((0, 3, 3), (0, 3, 4)): 200.0,
#  ((0, 3, 0),): -100.0,
#  ((0, 3, 2),): -200.0,
#  ((0, 3, 3),): -200.0,
#  ((0, 3, 4),): -200.0,
#  ((0, 4, 0), (0, 4, 1)): 200.0,
#  ((0, 4, 0), (0, 4, 2)): 200.0,
#  ((0, 4, 0), (0, 4, 3)): 200.0,
#  ((0, 4, 0), (0, 4, 4)): 200.0,
#  ((0, 4, 1), (0, 4, 2)): 200.0,
#  ((0, 4, 1), (0, 4, 3)): 200.0,
#  ((0, 4, 1), (0, 4, 4)): 200.0,
#  ((0, 4, 2), (0, 4, 3)): 200.0,
#  ((0, 4, 2), (0, 4, 4)): 200.0,
#  ((0, 4, 3), (0, 4, 4)): 200.0,
#  ((0, 4, 0),): -100.0,
#  ((0, 4, 2),): -200.0,
#  ((0, 4, 3),): -200.0,
#  ((0, 4, 4),): -200.0,
#  ((0, 0, 0), (0, 1, 0)): 200.0,
#  ((0, 0, 0), (0, 2, 0)): 200.0,
#  ((0, 0, 0), (0, 3, 0)): 200.0,
#  ((0, 0, 0), (0, 4, 0)): 200.0,
#  ((0, 1, 0), (0, 2, 0)): 200.0,
#  ((0, 1, 0), (0, 3, 0)): 200.0,
#  ((0, 1, 0), (0, 4, 0)): 200.0,
#  ((0, 2, 0), (0, 3, 0)): 200.0,
#  ((0, 2, 0), (0, 4, 0)): 200.0,
#  ((0, 3, 0), (0, 4, 0)): 200.0,
#  ((0, 0, 1), (0, 1, 1)): 200.0,
#  ((0, 0, 1), (0, 2, 1)): 200.0,
#  ((0, 0, 1), (0, 3, 1)): 200.0,
#  ((0, 0, 1), (0, 4, 1)): 200.0,
#  ((0, 1, 1), (0, 2, 1)): 200.0,
#  ((0, 1, 1), (0, 3, 1)): 200.0,
#  ((0, 1, 1), (0, 4, 1)): 200.0,
#  ((0, 2, 1), (0, 3, 1)): 200.0,
#  ((0, 2, 1), (0, 4, 1)): 200.0,
#  ((0, 3, 1), (0, 4, 1)): 200.0,
#  ((0, 0, 2), (0, 1, 2)): 200.0,
#  ((0, 0, 2), (0, 2, 2)): 200.0,
#  ((0, 0, 2), (0, 3, 2)): 200.0,
#  ((0, 0, 2), (0, 4, 2)): 200.0,
#  ((0, 1, 2), (0, 2, 2)): 200.0,
#  ((0, 1, 2), (0, 3, 2)): 200.0,
#  ((0, 1, 2), (0, 4, 2)): 200.0,
#  ((0, 2, 2), (0, 3, 2)): 200.0,
#  ((0, 2, 2), (0, 4, 2)): 200.0,
#  ((0, 3, 2), (0, 4, 2)): 200.0,
#  ((0, 0, 3), (0, 1, 3)): 200.0,
#  ((0, 0, 3), (0, 2, 3)): 200.0,
#  ((0, 0, 3), (0, 3, 3)): 200.0,
#  ((0, 0, 3), (0, 4, 3)): 200.0,
#  ((0, 1, 3), (0, 2, 3)): 200.0,
#  ((0, 1, 3), (0, 3, 3)): 200.0,
#  ((0, 1, 3), (0, 4, 3)): 200.0,
#  ((0, 2, 3), (0, 3, 3)): 200.0,
#  ((0, 2, 3), (0, 4, 3)): 200.0,
#  ((0, 3, 3), (0, 4, 3)): 200.0,
#  ((0, 0, 4), (0, 1, 4)): 200.0,
#  ((0, 0, 4), (0, 2, 4)): 200.0,
#  ((0, 0, 4), (0, 3, 4)): 200.0,
#  ((0, 0, 4), (0, 4, 4)): 200.0,
#  ((0, 1, 4), (0, 2, 4)): 200.0,
#  ((0, 1, 4), (0, 3, 4)): 200.0,
#  ((0, 1, 4), (0, 4, 4)): 200.0,
#  ((0, 2, 4), (0, 3, 4)): 200.0,
#  ((0, 2, 4), (0, 4, 4)): 200.0,
#  ((0, 3, 4), (0, 4, 4)): 200.0}

# %% [markdown]
# # Submitting to DWave

# %%
# pip install dwave-ocean-sdk
# pip install amazon-braket-ocean-plugin
import dwave.system
import braket.ocean_plugin

# %%
arn = "arn:aws:braket:::device/qpu/d-wave/DW_2000Q_6"
#arn = "arn:aws:braket:::device/qpu/d-wave/Advantage_system1"
my_bucket = f"amazon-braket-qbraid-jobs" # the name of the bucket
my_prefix = "tomeshteague-40gmail-2ecom" # the name of the folder in the bucket
s3_folder = (my_bucket, my_prefix)

shots = 10

sampler = dwave.system.EmbeddingComposite(
            braket.ocean_plugin.BraketDWaveSampler(s3_folder, arn)
        )

response = sampler.sample_qubo(qubo.Q, num_reads=shots)
record = response.record

solution = []
for row in record.sample:
    soln_dict = {}
    for var, assignment in zip(response.variables, row):
        soln_dict[var] = assignment
    solution.append(soln_dict)

return_data = [
    (s, e, n) for s, e, n in zip(solution, record.energy, record.num_occurrences)
]

return_recarray = np.rec.array(
    return_data, dtype=[("solution", "O"), ("energy", "<f8"), ("num_occurrences", "<i8")]
)

#print(return_recarray)

# %%
for i, res in enumerate(return_recarray):
    print('Anneal', i+1)
    state.print_routes(res['solution'])
    print('\tQUBO cost:', res['energy'])
    print()
